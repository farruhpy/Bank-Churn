# %%
# !unzip "archive.zip"
# Out:
# Archive:  archive.zip
#   inflating: test_cleaned.csv
#   inflating: train_cleaned.csv

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

from sklearn.metrics import mean_absolute_error, accuracy_score, confusion_matrix, f1_score

# %%
train = pd.read_csv("train_cleaned.csv")
train.head()
# Out:
#    Gender    Balance  NumOfProducts  IsActiveMember  Geography_France  \
# 0       0       0.00              2             0.0                 1
# 1       0       0.00              2             1.0                 1
# 2       0       0.00              2             0.0                 1
# 3       0  148882.54              1             1.0                 1
# 4       0       0.00              2             1.0                 0
#
#    Geography_Germany  Geography_Spain  Age_bin  Exited
# 0                  0                0        1       0
# 1                  0                0        1       0
# 2                  0                0        3       0
# 3                  0                0        1       0
# 4                  0                1        1       0

# %%
train.Exited.value_counts()
# Out:
# Exited
# 0    130113
# 1    130113
# Name: count, dtype: int64

# %%
test = pd.read_csv("test_cleaned.csv")
test.head()
# Out:
#    Gender    Balance  NumOfProducts  IsActiveMember  Geography_France  \
# 0       1       0.00              2             1.0                 1
# 1       1       0.00              1             0.0                 1
# 2       1       0.00              2             0.0                 1
# 3       0       0.00              1             0.0                 1
# 4       0  121263.62              1             0.0                 0
#
#    Geography_Germany  Geography_Spain  Age_bin
# 0                  0                0        0
# 1                  0                0        4
# 2                  0                0        1
# 3                  0                0        2
# 4                  1                0        2

# %%
x_train = train.drop("Exited", axis=1)
y_train = train.Exited

# %%
x_test = train.drop("Exited", axis=1)
y_test = train.Exited

# %%
LR_model = LinearRegression()

LR_model.fit(x_train, y_train)

predict=LR_model.predict(x_test)

# %%
from sklearn.metrics import mean_squared_error

# %%
mse = np.sqrt(mean_squared_error(y_test, predict))

# %%
print(mse)
# Out:
# 0.3945737034730355

# %%
predict
# Out:
# array([0.26020309, 0.06130611, 0.47988364, ..., 0.44320295, 1.1205231 ,
#        0.68431044])

# %%
pd.DataFrame(predict)
# Out:
#                0
# 0       0.260203
# 1       0.061306
# 2       0.479884
# 3       0.080136
# 4       0.057779
# ...          ...
# 260221  0.755467
# 260222  0.591727
# 260223  0.443203
# 260224  1.120523
# 260225  0.684310
#
# [260226 rows x 1 columns]

# %%
train['predicted']=pd.DataFrame(predict)

# %%
train
# Out:
#         Gender        Balance  NumOfProducts  IsActiveMember  \
# 0            0       0.000000              2        0.000000
# 1            0       0.000000              2        1.000000
# 2            0       0.000000              2        0.000000
# 3            0  148882.540000              1        1.000000
# 4            0       0.000000              2        1.000000
# ...        ...            ...            ...             ...
# 260221       1       0.000000              1        0.000000
# 260222       0       0.000000              1        1.000000
# 260223       1       0.000000              1        1.000000
# 260224       0  100156.868244              1        0.088564
# 260225       0       0.000000              1        0.000000
#
#         Geography_France  Geography_Germany  Geography_Spain  Age_bin  Exited  \
# 0                      1                  0                0        1       0
# ...

# %%
train[['Exited', 'predicted']]
# Out:
#         Exited  predicted
# 0            0   0.260203
# 1            0   0.061306
# 2            0   0.479884
# 3            0   0.080136
# 4            0   0.057779
# ...        ...        ...
# 260221       1   0.755467
# 260222       1   0.591727
# 260223       1   0.443203
# 260224       1   1.120523
# 260225       1   0.684310
#
# [260226 rows x 2 columns]

# %% [markdown]
# As you can see our model predicting almost excellent
